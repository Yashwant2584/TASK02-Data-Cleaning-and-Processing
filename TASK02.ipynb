# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashwant2584/TASK02-Data-Cleaning-and-Processing/blob/main/TASK02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing pandas library

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/01.Data Cleaning and Preprocessing.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observation      324 non-null    object
#  1   Y-Kappa          324 non-null    float64
#  2   ChipRate         319 non-null    float64
#  3   BF-CMratio       307 non-null    float64
#  4   BlowFlow         308 non-null    float64
#  5   ChipLevel4       323 non-null    float64
#  6   T-upperExt-2     322 non-null    float64
#  7   T-lowerExt-2     322 non-null    float64
#  8   UCZAA            299 non-null    float64
#  9   WhiteFlow-4      323 non-null    float64
#  10  AAWhiteSt-4      173 non-null    float64
#  11  AA-Wood-4        323 non-null    float64
#  12  ChipMoisture-4   323 non-null    float64
#  13  SteamFlow-4      323 non-null    float64
#  14  Lower-HeatT-3    322 non-null    float64
#  15  Upper-HeatT-3    322 non-null    float64
# ...

# %% [markdown]
# Describing the data

# %%
data.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  319.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.499095    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.358000   81.823000  1193.215250   213.527000
# 50%     20.845000   14.308000   86.739000  1273.138500   271.792000
# 75%     23.032500   15.517000   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...

# %%
data.tail(5)
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 319        347.286         310.970  1.523       513.956  ...        61.141
# 320        399.135         319.576  1.451       570.058  ...        67.667
# 321        373.633         314.591  1.457       549.306  ...        66.446
# 322        364.081         308.559  1.523       504.852  ...        61.054
# 323        356.289         310.482  1.474       497.375  ...        58.247
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %% [markdown]
#  **Handling Values**

# %% [markdown]
# 1. Drop_duplicates : Drop the duplicate values in the dataset.

# %%
data = data.drop_duplicates()

# %% [markdown]
# 2. Understanding Null Values
#
# True : describes null value
#
# False : describes no null value

# %%
data.isnull()
# Out:
#      Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0          False    False     False       False     False        False
# 1          False    False     False       False     False        False
# 2          False    False     False       False     False        False
# 3          False    False     False       False     False        False
# 4          False    False     False       False     False        False
# ..           ...      ...       ...         ...       ...          ...
# 298        False    False     False       False     False        False
# 299        False    False      True       False     False        False
# 300        False    False      True       False     False        False
# 301        False    False      True       False     False        False
# 307        False    False     False       False     False        False
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data.isnull().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             4
# BF-CMratio          14
# BlowFlow            13
# ChipLevel4           1
# T-upperExt-2         1
# T-lowerExt-2         1
# UCZAA               24
# WhiteFlow-4          1
# AAWhiteSt-4        141
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        1
# Upper-HeatT-3        1
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          1
# WeakWashF            1
# SteamHeatF-3         1
# T-Top-Chips-4        1
# SulphidityL-4      141
# dtype: int64

# %%
#It is just opposite to isnull function
#True : describes no null values
#False : describes nul values
data.notnull()
# Out:
#      Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0           True     True      True        True      True         True
# 1           True     True      True        True      True         True
# 2           True     True      True        True      True         True
# 3           True     True      True        True      True         True
# 4           True     True      True        True      True         True
# ..           ...      ...       ...         ...       ...          ...
# 298         True     True      True        True      True         True
# 299         True     True     False        True      True         True
# 300         True     True     False        True      True         True
# 301         True     True     False        True      True         True
# 307         True     True      True        True      True         True
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
# It Represent the total number of null values
data.isnull().sum().sum()
# Out:
# 352

# %% [markdown]
# 3.***Handling Null values***

# %% [markdown]
# 1. Fillna()

# %%
data2 = data.fillna(value=0)

# %%
data2.tail(5)
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98     0.000      85.034  1278.345      368.564
# 300    12-11:00    21.00     0.000      88.013  1307.722      278.842
# 301    12-12:00    21.40     0.000      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 298        354.803         311.041  1.635       532.419  ...        65.561
# 299        357.723         321.387  0.000       520.365  ...        65.729
# 300        357.438         323.757  0.000       553.070  ...        65.795
# 301        361.365         322.689  0.000       590.199  ...        71.456
# 307        351.263         332.485  1.522       631.514  ...        71.286
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %% [markdown]
# Row 299 to 301 & column chip rate shows the null values.

# %%
data2.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# 2. Forward Filling

# %%
data3 = data.fillna(method='pad')
# Out:
# <ipython-input-45-f14bc986d996>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3 = data.fillna(method='pad')

# %%
data3.tail(5)
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98    15.167      85.034  1278.345      368.564
# 300    12-11:00    21.00    15.167      88.013  1307.722      278.842
# 301    12-12:00    21.40    15.167      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 298        354.803         311.041  1.635       532.419  ...        65.561
# 299        357.723         321.387  1.635       520.365  ...        65.729
# 300        357.438         323.757  1.635       553.070  ...        65.795
# 301        361.365         322.689  1.635       590.199  ...        71.456
# 307        351.263         332.485  1.522       631.514  ...        71.286
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %% [markdown]
# row from 298 to 301 & chip rate column shows forward filling results.

# %% [markdown]
# 3. Backward Filling

# %%
data4 = data.fillna(method='bfill')
# Out:
# <ipython-input-47-2b77f275dcd0>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data4 = data.fillna(method='bfill')

# %%
data4.tail(5)
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98    14.308      85.034  1278.345      368.564
# 300    12-11:00    21.00    14.308      88.013  1307.722      278.842
# 301    12-12:00    21.40    14.308      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 298        354.803         311.041  1.635       532.419  ...        65.561
# 299        357.723         321.387  1.522       520.365  ...        65.729
# 300        357.438         323.757  1.522       553.070  ...        65.795
# 301        361.365         322.689  1.522       590.199  ...        71.456
# 307        351.263         332.485  1.522       631.514  ...        71.286
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %% [markdown]
# Row from 299 to 307 & column Chip rate shows the result of back filling.

# %% [markdown]
# **Cleaning Process**

# %%
import pandas as pd
from scipy import stats

# Convert relevant columns to numeric type
for col in data2.columns:
    if data2[col].dtype == 'object':
        try:
            data2[col] = pd.to_numeric(data2[col], errors='coerce')
        except ValueError:
            print(f"Could not convert column {col} to numeric.")

# Now calculate IQR
Q1 = data2.quantile(0.25)
Q3 = data2.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Observation            NaN
# Y-Kappa              4.550
# ChipRate             2.233
# BF-CMratio          10.912
# BlowFlow            96.766
# ChipLevel4         105.868
# T-upperExt-2        11.994
# T-lowerExt-2         7.609
# UCZAA                0.152
# WhiteFlow-4        100.098
# AAWhiteSt-4          6.143
# AA-Wood-4            1.486
# ChipMoisture-4       2.186
# SteamFlow-4          8.840
# Lower-HeatT-3        8.585
# Upper-HeatT-3        7.852
# ChipMass-4          19.347
# WeakLiquorF        180.613
# BlackFlow-2        280.829
# WeakWashF          267.219
# SteamHeatF-3         6.903
# T-Top-Chips-4        2.044
# SulphidityL-4       30.420
# dtype: float64

# %%
data2=data2[~((data2<(Q1-1.5*IQR))|(data2>(Q3+1.5*IQR))).any(axis=1)]

# %%
data2.describe()
# Out:
#        Observation     Y-Kappa    ChipRate  BF-CMratio     BlowFlow  \
# count          0.0  226.000000  226.000000  226.000000   226.000000
# mean           NaN   20.690487   14.673491   85.882181  1255.288916
# std            NaN    2.982916    1.297369    7.033155    47.896055
# min            NaN   12.480000   10.833000   68.645000  1084.083000
# 25%            NaN   18.457500   13.850000   80.984000  1221.926000
# 50%            NaN   20.775000   14.729000   84.967000  1280.291500
# 75%            NaN   23.010000   15.708000   91.178750  1289.254000
# max            NaN   27.600000   16.958000  108.104000  1351.240000
#
#        ChipLevel4   T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   \
# count   226.000000     226.000000      226.000000  226.000000    226.000000
# mean    264.664912     356.861681      325.341124    1.487146    603.242482
# std      74.345135       7.466897        5.557537    0.108054     61.052197
# ...
